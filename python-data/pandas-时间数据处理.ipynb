# %%
#时间数据处理
import pandas as pd
d = pd.Timestamp('2015-05-31 10:22')
print(d)
print(type(d))
print("年:",d.year)
print("月:",d.month)
print("日:",d.day)
print(d.hour,d.minute,d.second)
print("季度：",d.quarter)
print("是否是月底：",d.is_month_end)
#方法
print("星期几：",d.day_name())
print("转换为天：",d.to_period("D"))
print("转换为季度：",d.to_period("Q"))
# Out:
# 2015-05-31 10:22:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 年: 2015
# 月: 5
# 日: 31
# 10 22 0
# 季度： 2
# 是否是月底： True
# 星期几： Sunday
# 转换为天： 2015-05-31
# 转换为季度： 2015Q2

# %%
#字符串转换为时间类型
a = pd.to_datetime('2015-02-28 10:22')
print(a)
print(type(a))


#dataFrame日期转换
df = pd.DataFrame({
    'sales':[100,200,300],
    'date':['2025-06-01','2025-06-02','2025-06-03']
})
df['datetime'] = pd.to_datetime(df['date'])
df
print(df.info())
print(type(df['datetime']))
df['week'] = df['datetime'].dt.day_name()
df['datetime'].dt.year
# Out:
# 2015-02-28 10:22:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sales     3 non-null      int64
#  1   date      3 non-null      object
#  2   datetime  3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 204.0+ bytes
# None
# <class 'pandas.core.series.Series'>
# 0    2025
# 1    2025
# 2    2025
# Name: datetime, dtype: int32

# %%
#csv日期转换
df = pd.read_csv('地址.csv',parse_dates=['date'])
#日期数据作为索引
#df.set_index('date',inplace=True)#设置原来的df的索引
print(df.loc["2013-01":"2013-02"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 2
#       1 #csv日期转换
# ----> 2 df = pd.read_csv('地址.csv',parse_dates=['date'])
#       3 #日期数据作为索引
#       4 #df.set_index('date',inplace=True)#设置原来的df的索引
#       5 print(df.loc["2013-01":"2013-02"])
#
# ...

# %%
#时间间隔
d1 = pd.Timestamp('2013-01-01')
d2 = pd.Timestamp('2013-02-01')
d3 = d2 - d1
print(type(d3))
print(d3)
#创建时间序列
days = pd.date_range("2025-07-03","2026-02-09",freq="W")
days = pd.date_range("2025-07-03",periods=10,freq="W")#periods控制要多少个数据，freq控制间隔

print(days)
# Out:
# <class 'pandas._libs.tslibs.timedeltas.Timedelta'>
# 31 days 00:00:00

# %%
#重新采样
df.set_index('date',inplace=True)

# %%
df[["temp_max","temp_min"]].resample("YE").mean()

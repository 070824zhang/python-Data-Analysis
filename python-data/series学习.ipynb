# %%
#Series的创建
import pandas as pd
# s = pd.Series([10,2,3,4,5])
# print(s)
# Out:
# 0    10
# 1     2
# 2     3
# 3     4
# 4     5
# dtype: int64

# %%
#通过字典创建
s = pd.Series({"a":1,"b":2,"c":3})
print(s)
s1 = pd.Series(s,index=['a'])
print(s1)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# a    1
# dtype: int64
